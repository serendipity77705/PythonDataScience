# %% [markdown]
# # Introduction
#
# This assessment aims to evaluate your understanding and application of the concepts covered in the Data Analytics course. You will be tasked with analyzing a dataset related to remote work and mental health, utilizing various data manipulation, statistical analysis, and visualization techniques learned throughout the course. This exercise will help reinforce your skills in data handling, exploratory analysis, and drawing meaningful insights from data.
#
# ### Submission Details:
#
# The deadline for submission is 16 November at 11:59 PM. Specific submission details will be shared with you shortly.
#
# ### Passing Criteria:
#
# To successfully pass this assessment, you must achieve a score of 80% or higher.
# We encourage you to engage with the material and demonstrate your analytical skills. Good luck!
#
#
# ---

# %% [markdown]
# # Section 1 - Beginner (25%)

# %% [markdown]
# ## Shopping Cart System with Discounts
#
# Write a Python program to simulate a shopping cart system for an online store. The program will calculate the total cost of items, apply discounts, and check if the total exceeds a specified budget.

# %% [markdown]
# 1.	Variables and Lists:
#   - Define a `budget` variable with an initial value of 200.
#
#   - Create two empty lists called `item_names_list` and `item_prices_list` to store the name and price of each item separately.

# %%
# Write your code here
budget = 200
item_names_list = []
item_prices_list = []

# %% [markdown]
# 2. Functions:
#   - Write a function `add_item_to_cart(item_name, item_price)` that takes the item’s name and price as arguments, appends the name to item_names and the price to item_prices, and returns both updated lists.
#
#   - Write a function `calculate_total(item_prices)` that calculates and returns the total cost of all items in item_prices.
#
#     Conditions:
#     - If the total cost exceeds the budget after adding an item, print "Budget exceeded!" and stop adding more items.
#     - If the total cost is within budget and exceeds $100, apply a 10% discount on the total and print the discounted total.

# %%
# Write your code here
def add_item_to_cart(item_name, item_price):
  item_names_list.append(item_name)
  item_prices_list.append(item_price)

def calcualate_total(item_prices):
  total = 0
  for price in item_prices_list:
    total += int(price)
    if total > budget:
      print("Budget exceeded!")
      break
    elif total < budget and total > 100:
      total *= 0.9
      print(f"Discounted total: {total}")
      continue
  return total

# %% [markdown]
# 3.	Loop and Input:
#   - Start the input only once the user says 'start'
#   - Use a loop to allow the user to add items to the cart by entering an item name and price. The loop should stop when the user types 'done'.
#   - For each item, add it to item_names and item_prices using add_item_to_cart, then update the total cost using calculate_total.
#
# Output:
#   - After the loop ends, display the final cart with each item and its price, the initial total, any applicable discount, and the final total.

# %%
# start = input("Enter 'start' to start: ")
# print("Enter 'done' to stop adding items.")
# if start == 'start':
#   while start != 'done' or start == '':
#     item_name = input("Enter item name: ")
#     item_price = int(input("Enter item price: "))
#     add_item_to_cart(item_name, item_price)
#     total = calcualate_total(item_prices_list)
#     start = input("Enter 'done' to stop adding items")

# print("Final cart:")
# for i in range(len(item_names_list)):
#   print(f"Item name: {item_names_list[i]}, Item price: {item_prices_list[i]}, Item total: {total}")

total = []
print("Enter 'start' to start")
if(input() == 'start'):
  while True:
    item_name = input("Enter item name or type 'done' when finished: ")
    if item_name == 'done':
      break
    item_price = float(input(f"Enter price for {item_name}: "))
    add_item_to_cart(item_name, item_price)
    total.append(calcualate_total(item_prices_list))
# Out:
# Enter 'start' to start
# start
# Enter item name or type 'done' when finished: thing
# Enter price for thing: 3
# Enter item name or type 'done' when finished: bread
# Enter price for bread: 1
# Enter item name or type 'done' when finished: done

# %%
# Write your code here
print("Final cart:")
total_prices = calcualate_total(item_prices_list)
for i in range(len(item_names_list)):
  print(f"Item name: {item_names_list[i]}, Item price: {item_prices_list[i]}, Item total: {total[i]}")
print(f"Final total: {total_prices}")
# Out:
# Final cart:
# Item name: thing, Item price: 3.0, Item total: 3
# Item name: bread, Item price: 1.0, Item total: 4
# Final total: 4

# %% [markdown]
# # Section 2 - Intermidiate (55%) - Remote Work and Mental Health Analysis
#
# Dataset source: Kaggle (https://www.kaggle.com/datasets/waqi786/remote-work-and-mental-health)

# %% [markdown]
# ## Objective:
# - In the following sections, you will explore the "Remote Work and Mental Health" dataset using Python and different data science libraries such as Pandas, NumPy and Matplotlib.
# - Follow the instructions below to complete each task. Please provide code for each question and any observations as comments when necessary.

# %%
# Import necessary modules and libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## 1. Load Dataset (2 marks)
# - Instructions: Load the dataset using Pandas and display few rows.
# - Question: Describe the overall structure (rows, columns, data types) as a comment at the end of your code.

# %%
4# Write code here
df = pd.read_csv("Impact_of_Remote_Work_on_Mental_Health.csv")
df.head()

# The dataset has 20 columns and many rows. The types of data in this dataset is
# varied, there are some columns that hav ints (Age, Years_of_Experience, Hours_Worked_Per_Week, etc)
# while others are strings (Employee_ID, Gender, etc). The dat checks many different things
# relating to workers, including whether they work from the office or home, physical activity, region etc.
# Out:
#   Employee_ID  Age      Gender           Job_Role    Industry  \
# 0     EMP0001   32  Non-binary                 HR  Healthcare
# 1     EMP0002   40      Female     Data Scientist          IT
# 2     EMP0003   59  Non-binary  Software Engineer   Education
# 3     EMP0004   27        Male  Software Engineer     Finance
# 4     EMP0005   49        Male              Sales  Consulting
#
#    Years_of_Experience Work_Location  Hours_Worked_Per_Week  \
# 0                   13        Hybrid                     47
# 1                    3        Remote                     52
# 2                   22        Hybrid                     46
# 3                   20        Onsite                     32
# 4                   32        Onsite                     35
#
#    Number_of_Virtual_Meetings  Work_Life_Balance_Rating Stress_Level  \
# 0                           7                         2       Medium
# 1                           4                         1       Medium
# 2                          11                         5       Medium
# 3                           8                         4         High
# 4                          12                         2         High
#
#   Mental_Health_Condition Access_to_Mental_Health_Resources  \
# 0              Depression                                No
# 1                 Anxiety                                No
# 2                 Anxiety                                No
# 3              Depression                               Yes
# 4                     NaN                               Yes
#
#   Productivity_Change  Social_Isolation_Rating Satisfaction_with_Remote_Work  \
# 0            Decrease                        1                   Unsatisfied
# 1            Increase                        3                     Satisfied
# 2           No Change                        4                   Unsatisfied
# 3            Increase                        3                   Unsatisfied
# 4            Decrease                        3                   Unsatisfied
#
#    Company_Support_for_Remote_Work Physical_Activity Sleep_Quality  \
# 0                                1            Weekly          Good
# 1                                2            Weekly          Good
# 2                                5               NaN          Poor
# 3                                3               NaN          Poor
# 4                                3            Weekly       Average
#
#           Region
# 0         Europe
# 1           Asia
# 2  North America
# 3         Europe
# 4  North America

# %% [markdown]
# ## 2. Display 'n' Rows (3 marks)
# - Instructions: Display the first 13 rows of the dataset.

# %%
# Write code here
first_thirteen = df.head(13)
first_thirteen
# Out:
#    Employee_ID  Age             Gender           Job_Role       Industry  \
# 0      EMP0001   32         Non-binary                 HR     Healthcare
# 1      EMP0002   40             Female     Data Scientist             IT
# 2      EMP0003   59         Non-binary  Software Engineer      Education
# 3      EMP0004   27               Male  Software Engineer        Finance
# 4      EMP0005   49               Male              Sales     Consulting
# 5      EMP0006   59         Non-binary              Sales             IT
# 6      EMP0007   31  Prefer not to say              Sales             IT
# 7      EMP0008   42         Non-binary     Data Scientist  Manufacturing
# 8      EMP0009   56  Prefer not to say     Data Scientist     Healthcare
# 9      EMP0010   30             Female                 HR             IT
# 10     EMP0011   33         Non-binary  Software Engineer        Finance
# 11     EMP0012   47             Female          Marketing     Consulting
# 12     EMP0013   40             Female          Marketing     Consulting
#
#     Years_of_Experience Work_Location  Hours_Worked_Per_Week  \
# 0                    13        Hybrid                     47
# 1                     3        Remote                     52
# 2                    22        Hybrid                     46
# 3                    20        Onsite                     32
# 4                    32        Onsite                     35
# 5                    31        Hybrid                     39
# 6                    24        Remote                     51
# 7                     6        Onsite                     54
# 8                     9        Hybrid                     24
# 9                    28        Hybrid                     57
# 10                   17        Remote                     48
# 11                   31        Hybrid                     26
# 12                    1        Remote                     21
#
#     Number_of_Virtual_Meetings  Work_Life_Balance_Rating Stress_Level  \
# 0                            7                         2       Medium
# 1                            4                         1       Medium
# 2                           11                         5       Medium
# 3                            8                         4         High
# 4                           12                         2         High
# 5                            3                         4         High
# 6                            7                         3          Low
# 7                            7                         3       Medium
# 8                            4                         2         High
# 9                            6                         1          Low
# 10                           3                         3         High
# 11                          12                         4       Medium
# 12                           7                         2         High
#
#    Mental_Health_Condition Access_to_Mental_Health_Resources  \
# 0               Depression                                No
# 1                  Anxiety                                No
# 2                  Anxiety                                No
# 3               Depression                               Yes
# 4                      NaN                               Yes
# 5                      NaN                                No
# 6                  Anxiety                               Yes
# 7               Depression                                No
# 8                      NaN                               Yes
# 9               Depression                               Yes
# 10                     NaN                               Yes
# 11                     NaN                               Yes
# 12              Depression                               Yes
#
#    Productivity_Change  Social_Isolation_Rating Satisfaction_with_Remote_Work  \
# 0             Decrease                        1                   Unsatisfied
# 1             Increase                        3                     Satisfied
# 2            No Change                        4                   Unsatisfied
# 3             Increase                        3                   Unsatisfied
# 4             Decrease                        3                   Unsatisfied
# 5             Increase                        5                   Unsatisfied
# 6             Decrease                        5                       Neutral
# 7             Decrease                        5                     Satisfied
# 8             Decrease                        2                   Unsatisfied
# 9             Decrease                        2                       Neutral
# 10            Decrease                        4                     Satisfied
# 11           No Change                        4                       Neutral
# 12            Decrease                        2                       Neutral
#
#     Company_Support_for_Remote_Work Physical_Activity Sleep_Quality  \
# 0                                 1            Weekly          Good
# 1                                 2            Weekly          Good
# 2                                 5               NaN          Poor
# 3                                 3               NaN          Poor
# 4                                 3            Weekly       Average
# 5                                 1               NaN       Average
# 6                                 3             Daily          Poor
# 7                                 4               NaN       Average
# 8                                 4             Daily          Poor
# 9                                 1            Weekly          Poor
# 10                                2            Weekly       Average
# 11                                3            Weekly          Poor
# 12                                1            Weekly          Good
#
#            Region
# 0          Europe
# 1            Asia
# 2   North America
# 3          Europe
# 4   North America
# 5   South America
# 6            Asia
# 7   North America
# 8          Europe
# 9   North America
# 10        Oceania
# 11         Africa
# 12         Europe

# %% [markdown]
# - Instructions: Display the last 7 rows of the dataset

# %%
# Write code here
last_seven = df.tail(7)
last_seven
# Out:
#      Employee_ID  Age             Gender   Job_Role    Industry  \
# 4993     EMP4994   35         Non-binary  Marketing      Retail
# 4994     EMP4995   40  Prefer not to say  Marketing          IT
# 4995     EMP4996   32               Male      Sales  Consulting
# 4996     EMP4997   39             Female      Sales  Healthcare
# 4997     EMP4998   42             Female      Sales  Healthcare
# 4998     EMP4999   27             Female      Sales  Healthcare
# 4999     EMP5000   29               Male         HR          IT
#
#       Years_of_Experience Work_Location  Hours_Worked_Per_Week  \
# 4993                   12        Hybrid                     32
# 4994                   17        Hybrid                     52
# 4995                    4        Onsite                     24
# 4996                   27        Onsite                     48
# 4997                   21        Hybrid                     34
# 4998                   26        Remote                     58
# 4999                   30        Onsite                     20
#
#       Number_of_Virtual_Meetings  Work_Life_Balance_Rating Stress_Level  \
# 4993                          13                         5       Medium
# 4994                           1                         2       Medium
# 4995                           2                         5         High
# 4996                          15                         1          Low
# 4997                           1                         4         High
# 4998                           0                         5          Low
# 4999                          15                         1          Low
#
#      Mental_Health_Condition Access_to_Mental_Health_Resources  \
# 4993                     NaN                               Yes
# 4994                 Burnout                               Yes
# 4995                 Burnout                               Yes
# 4996              Depression                               Yes
# 4997                 Burnout                                No
# 4998                     NaN                               Yes
# 4999              Depression                               Yes
#
#      Productivity_Change  Social_Isolation_Rating  \
# 4993            Decrease                        2
# 4994            Increase                        3
# 4995            Decrease                        4
# 4996            Decrease                        1
# 4997            Increase                        3
# 4998            Increase                        3
# 4999           No Change                        3
#
#      Satisfaction_with_Remote_Work  Company_Support_for_Remote_Work  \
# 4993                     Satisfied                                3
# 4994                       Neutral                                5
# 4995                       Neutral                                1
# 4996                     Satisfied                                1
# 4997                     Satisfied                                1
# 4998                   Unsatisfied                                4
# 4999                   Unsatisfied                                5
#
#      Physical_Activity Sleep_Quality   Region
# 4993             Daily          Good     Asia
# 4994             Daily          Good  Oceania
# 4995            Weekly       Average     Asia
# 4996               NaN       Average   Africa
# 4997             Daily          Poor  Oceania
# 4998             Daily       Average     Asia
# 4999               NaN          Poor     Asia

# %% [markdown]
# ## 3. Find the Number of Null Values in the Dataset (2 mark)

# %%
# Write code here
df.isna().sum()
# Out:
# Employee_ID                             0
# Age                                     0
# Gender                                  0
# Job_Role                                0
# Industry                                0
# Years_of_Experience                     0
# Work_Location                           0
# Hours_Worked_Per_Week                   0
# Number_of_Virtual_Meetings              0
# Work_Life_Balance_Rating                0
# Stress_Level                            0
# Mental_Health_Condition              1196
# Access_to_Mental_Health_Resources       0
# Productivity_Change                     0
# Social_Isolation_Rating                 0
# Satisfaction_with_Remote_Work           0
# Company_Support_for_Remote_Work         0
# Physical_Activity                    1629
# Sleep_Quality                           0
# Region                                  0
# dtype: int64

# %% [markdown]
# ## 4. Statistical Summary for Numeric Columns (10 marks)
# Instructions: Use individual commands to find the statistical summary.

# %% [markdown]
# - Count

# %%
# Write code here
df.count()
# Out:
# Employee_ID                          5000
# Age                                  5000
# Gender                               5000
# Job_Role                             5000
# Industry                             5000
# Years_of_Experience                  5000
# Work_Location                        5000
# Hours_Worked_Per_Week                5000
# Number_of_Virtual_Meetings           5000
# Work_Life_Balance_Rating             5000
# Stress_Level                         5000
# Mental_Health_Condition              3804
# Access_to_Mental_Health_Resources    5000
# Productivity_Change                  5000
# Social_Isolation_Rating              5000
# Satisfaction_with_Remote_Work        5000
# Company_Support_for_Remote_Work      5000
# Physical_Activity                    3371
# Sleep_Quality                        5000
# Region                               5000
# dtype: int64

# %% [markdown]
# - Mean

# %%
# Write code here
float_columns = df.select_dtypes(include=['float64', 'int64'])
mean_values = float_columns.mean()
mean_values
# Out:
# Age                                40.9950
# Years_of_Experience                17.8102
# Hours_Worked_Per_Week              39.6146
# Number_of_Virtual_Meetings          7.5590
# Work_Life_Balance_Rating            2.9842
# Social_Isolation_Rating             2.9938
# Company_Support_for_Remote_Work     3.0078
# dtype: float64

# %% [markdown]
# - Standard Deviation

# %%
# Write code here
sd_values = float_columns.std()
sd_values
# Out:
# Age                                11.296021
# Years_of_Experience                10.020412
# Hours_Worked_Per_Week              11.860194
# Number_of_Virtual_Meetings          4.636121
# Work_Life_Balance_Rating            1.410513
# Social_Isolation_Rating             1.394615
# Company_Support_for_Remote_Work     1.399046
# dtype: float64

# %% [markdown]
# - Quartiles

# %%
# Write code here
float_columns.quantile([0.25, 0.5, 0.75])
# Out:
#        Age  Years_of_Experience  Hours_Worked_Per_Week  \
# 0.25  31.0                  9.0                   29.0
# 0.50  41.0                 18.0                   40.0
# 0.75  51.0                 26.0                   50.0
#
#       Number_of_Virtual_Meetings  Work_Life_Balance_Rating  \
# 0.25                         4.0                       2.0
# 0.50                         8.0                       3.0
# 0.75                        12.0                       4.0
#
#       Social_Isolation_Rating  Company_Support_for_Remote_Work
# 0.25                      2.0                              2.0
# 0.50                      3.0                              3.0
# 0.75                      4.0                              4.0

# %% [markdown]
# ## 5. Calculate Extrema (2 marks)

# %%
# Write code here
float_columns.agg(['min', 'max'])
# Out:
#      Age  Years_of_Experience  Hours_Worked_Per_Week  \
# min   22                    1                     20
# max   60                   35                     60
#
#      Number_of_Virtual_Meetings  Work_Life_Balance_Rating  \
# min                           0                         1
# max                          15                         5
#
#      Social_Isolation_Rating  Company_Support_for_Remote_Work
# min                        1                                1
# max                        5                                5

# %% [markdown]
# ## 6. Find Unique Values in a Categorical Column (3 marks)
#
# - Instructions: Identify the unique values in the `job_role` column (2 marks)
# - Question: How many unique roles are represented in the dataset? (1 mark)

# %%
# Write code here
job_roles = df['Job_Role'].unique()
job_roles
# There are 7 unique roles in the dataset
# Out:
# array(['HR', 'Data Scientist', 'Software Engineer', 'Sales', 'Marketing',
#        'Designer', 'Project Manager'], dtype=object)

# %% [markdown]
# ## 7. Group Data and Calculate Mean (4 marks)
# - Instructions: Group the dataset by `job_role` and calculate the mean of the `Work_Life_Balance_Rating` for each role.
# - Question: Which job role has the highest average mental health index?

# %%
# Write code here
job_life_balance = df.groupby('Job_Role')['Work_Life_Balance_Rating']
job_life_balance.mean()
# Out:
# Job_Role
# Data Scientist       3.007184
# Designer             2.966805
# HR                   2.930168
# Marketing            2.945827
# Project Manager      2.960705
# Sales                3.043656
# Software Engineer    3.033755
# Name: Work_Life_Balance_Rating, dtype: float64

# %% [markdown]
# ## 8. Filter Data Based on Condition (4 marks)
# - Instructions: Filter the dataset to show only rows where `work_hours_per_week` is greater than 40.
# - Question: How many employees are working overtime?

# %%
# Write code here
df_work_hours = df[df['Hours_Worked_Per_Week'] > 40]
df_work_hours
# Out:
#      Employee_ID  Age             Gender           Job_Role       Industry  \
# 0        EMP0001   32         Non-binary                 HR     Healthcare
# 1        EMP0002   40             Female     Data Scientist             IT
# 2        EMP0003   59         Non-binary  Software Engineer      Education
# 6        EMP0007   31  Prefer not to say              Sales             IT
# 7        EMP0008   42         Non-binary     Data Scientist  Manufacturing
# ...          ...  ...                ...                ...            ...
# 4991     EMP4992   60             Female     Data Scientist             IT
# 4992     EMP4993   55  Prefer not to say    Project Manager     Consulting
# 4994     EMP4995   40  Prefer not to say          Marketing             IT
# 4996     EMP4997   39             Female              Sales     Healthcare
# 4998     EMP4999   27             Female              Sales     Healthcare
#
#       Years_of_Experience Work_Location  Hours_Worked_Per_Week  \
# 0                      13        Hybrid                     47
# 1                       3        Remote                     52
# 2                      22        Hybrid                     46
# 6                      24        Remote                     51
# 7                       6        Onsite                     54
# ...                   ...           ...                    ...
# 4991                    9        Hybrid                     57
# 4992                   21        Hybrid                     45
# 4994                   17        Hybrid                     52
# 4996                   27        Onsite                     48
# 4998                   26        Remote                     58
#
#       Number_of_Virtual_Meetings  Work_Life_Balance_Rating Stress_Level  \
# 0                              7                         2       Medium
# 1                              4                         1       Medium
# 2                             11                         5       Medium
# 6                              7                         3          Low
# 7                              7                         3       Medium
# ...                          ...                       ...          ...
# 4991                           4                         2          Low
# 4992                           7                         2         High
# 4994                           1                         2       Medium
# 4996                          15                         1          Low
# 4998                           0                         5          Low
#
#      Mental_Health_Condition Access_to_Mental_Health_Resources  \
# 0                 Depression                                No
# 1                    Anxiety                                No
# 2                    Anxiety                                No
# 6                    Anxiety                               Yes
# 7                 Depression                                No
# ...                      ...                               ...
# 4991                 Burnout                               Yes
# 4992                 Anxiety                                No
# 4994                 Burnout                               Yes
# 4996              Depression                               Yes
# 4998                     NaN                               Yes
#
#      Productivity_Change  Social_Isolation_Rating  \
# 0               Decrease                        1
# 1               Increase                        3
# 2              No Change                        4
# 6               Decrease                        5
# 7               Decrease                        5
# ...                  ...                      ...
# 4991            Increase                        4
# 4992           No Change                        2
# 4994            Increase                        3
# 4996            Decrease                        1
# 4998            Increase                        3
#
#      Satisfaction_with_Remote_Work  Company_Support_for_Remote_Work  \
# 0                      Unsatisfied                                1
# 1                        Satisfied                                2
# 2                      Unsatisfied                                5
# 6                          Neutral                                3
# 7                        Satisfied                                4
# ...                            ...                              ...
# 4991                     Satisfied                                5
# 4992                     Satisfied                                3
# 4994                       Neutral                                5
# 4996                     Satisfied                                1
# 4998                   Unsatisfied                                4
#
#      Physical_Activity Sleep_Quality         Region
# 0               Weekly          Good         Europe
# 1               Weekly          Good           Asia
# 2                  NaN          Poor  North America
# 6                Daily          Poor           Asia
# 7                  NaN       Average  North America
# ...                ...           ...            ...
# 4991            Weekly       Average        Oceania
# 4992             Daily          Poor         Africa
# 4994             Daily          Good        Oceania
# 4996               NaN       Average         Africa
# 4998             Daily       Average           Asia
#
# [2384 rows x 20 columns]

# %% [markdown]
# ## 9 . Histogram of Work Hours per Week (5 marks)
# - Instructions: Create a histogram of `Hours_Worked_Per_Week` (4 marks).
# - Question: Describe the distribution of work hours. Are most employees working around a certain number of hours per week? (1 mark)

# %%
# Write code here
plt.hist(df['Hours_Worked_Per_Week'], bins=20, color="green", edgecolor="black")
plt.xlabel('Hours Worked Per Week')
plt.ylabel('Number of Workers ')
plt.title('Distribution of Hours Worked Per Week')
plt.show()
# Most employees seem to be working 58-60 hours, but there is not significannt increase in
# numbers for other distributions.

# %% [markdown]
# ## 10. Scatter Plot of Work Hours vs. Mental Health Index (4 marks)
# - Instructions: Create a scatter plot with `Hours_Worked_Per_Week` on the x-axis and `Years_of_Experience` on the y-axis.

# %%
# Write code here
x = df['Hours_Worked_Per_Week']
y = df['Years_of_Experience']
plt.scatter(x, y, color="green")
plt.title('Hours Worked Per Week against Years of Experience')
plt.xlabel('Hours Worked Per Week')
plt.ylabel('Years of Experience')
plt.show()

# %% [markdown]
# ## 11. Bar Chart of Average Mental Health Index by Job Role (5 marks)
# - Instructions: Create a bar chart showing the average `Work_Life_Balance_Rating` for each `Job_Role` (4 marks).
# - Question: Which job roles have the highest and lowest average mental health index? (1 mark)

# %%
# Write code here
plt.figure(figsize=(15,10))
plt.bar(job_roles, job_life_balance.mean())
plt.xlabel('Job Role')
plt.ylabel('Average Work Life Balance Rating')
plt.title('Mental Health Index By Job Role')
plt.show()
# all the roles seem to have the same general average work life balance, which is about 3.0
# the highest is Designer while the lowest is Software Engineer

# %% [markdown]
# ## 12. Pie Chart of Workload Level Distribution (5 marks)
# - Instructions: Use a pie chart to show the proportion of `Access_to_Mental_Health_Resources` (Yes and no) in the dataset (4 marks).
# - Question: What percentage of employees have access to mental health resources? (1 mark)

# %%
# Write code here
plt.pie(df['Access_to_Mental_Health_Resources'].value_counts(), labels=df['Access_to_Mental_Health_Resources'].unique(), autopct='%1.1f%%')
plt.title('Pie Chart of Workload Level Distribution')
plt.show()
# 48.9% of employees have access to mental health resources

# %% [markdown]
# ## 13. Scatter Plot of Years of Experience vs. Mental Health Index (6 marks)
# - Instructions: Create a scatter plot with `age` on the x-axis and `Social_Isolation_Rating` on the y-axis (4 marks).
# - Question: Do you observe any trends or relationships between age and social isolation? Is there a noticeable impact of age on isoloation? (2 marks)

# %%
# Write code here
x = df['Age']
y = df['Social_Isolation_Rating']
plt.scatter(x, y, color="green")
plt.title('Age against Social Isolation Rating')
plt.xlabel('Age')
plt.ylabel('Social Isolation Rating')
plt.show()
# There really isn't a trend between the ages, so there is no correlation.

# %% [markdown]
# # Section 3 - Long Answer/Advanced (20%)

# %% [markdown]
# ## Job Role and Workload Level Impact on Mental Health
#
# Instructions: Investigate the influence of job roles and workload level on the mental health index.
# - Create a new column `workload_level` that labels each entry as "High" if the `Hours_Worked_Per_Week` is above its mean, otherwise "Low." (5 marks)
# - Group the dataset by `Industry` and calculate the average `Hours_Worked_Per_Week` for each combination. (5 marks)
# - Use a bar chart to display the average `Stress_Level` for each job role, with separate bars for high and low stress levels. (5 marks)
# - Analyze the results: Which job roles and workload levels appear to have the greatest impact on mental health? (5 marks)

# %%
# Write code here
industry = df.groupby('Industry')
industry_mean_hours = industry['Hours_Worked_Per_Week'].mean()
mean_hours = df['Hours_Worked_Per_Week'].mean()

# breaking things into high and low stress levels
df['workload_level'] = np.where(df['Hours_Worked_Per_Week'] > mean_hours, 'High', 'Low')

high_stress = df[df['Stress_Level'] == 'High'].count()
low_stress = df[df['Stress_Level'] == 'Low'].count()
average_stress = df.groupby('Stress_Level')['Hours_Worked_Per_Week'].mean()

# grouping stress by job roles
high_stress_hours = high_stress.groupby('Job_Role')['Hours_Worked_Per_Week'].mean()
low_stress_hours = low_stress.groupby('Job_Role')['Hours_Worked_Per_Week'].mean()

# gives the job role labels
x = high_stress_hours.index

# used to separate high and low so they're not over each other
width = 0.25

plt.figure(figsize=(10,5))
plt.bar(x, high_stress_hours.values, width, color='red', label='High Stress')
plt.bar(np.arange(len(x)) + width, low_stress_hours.values, width, color='green', label='Low Stress')


plt.xlabel('Industry')
plt.ylabel('Average Hours Worked Per Week')
plt.title('Average Hours Worked Per Week by Industry Correlated to Stress Level')
plt.legend()
plt.show()

# the job that shows the largest difference between high and low stress levels is
# data scientist
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-55-88c841c2ed4e> in <cell line: 14>()
#      12
#      13 # grouping stress by job roles
# ---> 14 high_stress_hours = high_stress.groupby('Job_Role')['Hours_Worked_Per_Week'].mean()
#      15 low_stress_hours = low_stress.groupby('Job_Role')['Hours_Worked_Per_Week'].mean()
#      16
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    2245         axis = self._get_axis_number(axis)
#    2246
# -> 2247         return SeriesGroupBy(
#    2248             obj=self,
#    2249             keys=by,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1327
#    1328         if grouper is None:
# -> 1329             grouper, exclusions, obj = get_grouper(
#    1330                 obj,
#    1331                 keys,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/grouper.py in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#    1041                 in_axis, level, gpr = False, gpr, None
#    1042             else:
# -> 1043                 raise KeyError(gpr)
#    1044         elif isinstance(gpr, Grouper) and gpr.key is not None:
#    1045             # Add key to exclusions
#
# KeyError: 'Job_Role'
